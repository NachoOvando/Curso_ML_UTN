# %% [markdown]
# # Curso Machine learning UTN

# %% [markdown]
# ## Clase 1

# %% [markdown]
# ### Web Scraping y Aprendizaje Supervisado 1

# %% [markdown]
# #### Web Scraping

# %% [markdown]
# Biblioteca para hacer llamadas API: request
#
# Devuelve:
# - Status code= respuesta http (200, 404, etc)
# - headers
# - contenido
#
# La libreria BeautifulSoup es para extraer y manipular datos Web. Usado para archivos html o xml

# %% [markdown]
# from bs4 import BeautifulSoup
# import requests
#
# Puedo buscar con soup algunos elementos del codigo html, por ejemplos class, id, etc
#
# Aun que trabaja mas con paginas estaticas. Para interactuar con el codigo puedo ir hacia los botones y aplicar los eventos.

# %% [markdown]
# #### Regresion Lineal

# %% [markdown]
# Generalmente estos modelos, una vez entrenados (con train y test) ya se obtiene la mejor solucion. Esto se debe a su simplicidad.

# %% [markdown]
# ## Clase 2

# %% [markdown]
# ### Regresion Logistica

# %% [markdown]
# Por logaritmo se refiere a la forma de estimar o clasificar valores segun un conjunto de muestra.
# El objetivo es minimizar la funcion objetivo J, se trabaja con clasificaciones BINARIAS.
# Con la funcion de probabilidad estima la probabilidad de la clasificacion (1 o 0)
# ![image.png](attachment:d8dbb3a0-38f8-48b1-b435-0c9420368e09.png)

# %% [markdown]
# La evaluacion del modelo, se analiza con el mashgrid() o algun grafico similar. La idea es ver como esta clasificando los datos el algoritmo, desde el punto de vista.
# En el grafico antes, seria algo similar al cuadrante, que diferencia los tipos de clasificaciones predictas.

# %% [markdown]
# ### Regresion Multilineal

# %% [markdown]
# sns.pairplot() --> es usado para analizar la relacion entre variables
# dftrain[[]].corr() es para ver la correlacion entre variables

# %% [markdown]
# ### SVM

# %% [markdown]
# es similar a la regresion logistica, pero la diferencia esta en que la funcion objetivo a minimizar.
# Valores de C muy chicos va a hacer que el ajuste va a estar subajustado, caso contrario esta sobreajustado (overfitting).
# ![image.png](attachment:be58f8fe-a314-4202-ad73-42a2e4e864f1.png)
# Ejemplo:
# ![image.png](attachment:93c19d4c-a41f-4815-8da1-8c8f928aea6c.png)

# %% [markdown]
# Definiendo el tipo de kernel, sirve para poder variar el tipo de clasificacion entre variables, diferenciando entre clasificacion lineal, gaussiana, polinomica, etc.
# Ejemplo:
# ![image.png](attachment:727cc4d1-781c-4226-953c-bb3d4252ee9a.png)

# %% [markdown]
# ## Clase 3

# %% [markdown]
# Los alpha, definen como va a ser la velocidad de convergencia de la solucion. Define los pasos del gradiente descendiente. Learning Rate
# Es la velocidad en la que va a ajustar los datos.

# %% [markdown]
# ![image.png](attachment:a94bd70b-5681-4ada-adf4-5c35c591badf.png)
# ![image.png](attachment:c47e3b22-3555-4bf8-9a11-7e271196cbc4.png)

# %% [markdown]
# Para 10000 datos, cada epocas hace referencia al paso de todos los datos una sola vez. Por ejemplo 1 epoca pasa por 10000 datos.
# la matriz de confusion sirve para ver cual es la precision del algoritmo, como fue que se clasifico el algoritmo.

# %% [markdown]
# ## Clase 4

# %% [markdown]
# ### KNN
# Previamente se entrena el modelo de clasificacion de manera supervisada.
# ![image.png](attachment:56ba807f-1d42-4321-9c9e-73f5ca5a6f52.png)
# ![image.png](attachment:cf1fd50d-ff68-4875-ba59-f6c8e0d5cb89.png)
